# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Install Dependencies
#
# Install kagglehub for dataset access:

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = ""

# %% [markdown]
# ## Dataset 1: REFUGE2 and REFUGE2Cross Dataset
#
# Load the latest version of the refuge2-and-refuge2cross-dataset

# %%
# Load the latest version of the refuge2-and-refuge2cross-dataset
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "ferencjuhsz/refuge2-and-refuge2cross-dataset",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())

# %% [markdown]
# ## Dataset 2: Cornea in Diabetes
#
# **TEMPLATE BLOCK - Dataset code not available**
#
# Name of Dataset: Cornea in Diabetes
#
# Review the documentation of the Cornea in Diabetes dataset. This dataset cannot be included in this notebook via code. To parse and manually harmonize later.

# %%
# Load the latest version of the cornea-in-diabetes dataset
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "drbasanthkb/cornea-in-diabetes",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())

# %% [markdown]
# ## Dataset 3: Ocular Disease Dataset
#
# Review of the documentation of the ocular disease dataset

# %%
# Load the latest version of the fundus-images dataset
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "arjunbhushan005/fundus-images",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())

# %% [markdown]
# ## Dataset 4: Retina Blood Vessel
#
# Review the documentation of the Retina Blood Vessel dataset. This dataset cannot be included in this notebook via code. To parse and manually harmonize later.

# %% [markdown]
# ## Dataset 5: AMD P Dataset
#
# Load the latest version of the amdp-dataset

# %%
# Load the latest version of the amdp-dataset
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "datasetengineer/amdp-dataset",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
